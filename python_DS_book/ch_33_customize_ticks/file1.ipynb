# %%
#Major and minor ticks

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
plt.style.use('classic')
import numpy as np

# %%
ax = plt.axes(xscale='log', yscale='log')
ax.set(xlim=(1, 1E3), ylim=(1, 1E3))
ax.grid(True);

# %%
# Hide ticks or labels
ax = plt.axes()
rng = np.random.default_rng(1701)
ax.plot(rng.random(50))
ax.grid()

ax.xaxis.set_major_formatter(plt.NullFormatter()) #Minor tick, no labels will be shown
ax.yaxis.set_major_locator(plt.NullLocator())

# %%
ax = plt.axes()
rng = np.random.default_rng(1701)
ax.plot(rng.random(50))
ax.grid()

# %%
# faces
fig, ax = plt.subplots(5, 5, figsize=(5, 5))
fig.subplots_adjust(hspace=0, wspace=0)

# Get some face data from Scikit-learn
from sklearn.datasets import fetch_olivetti_faces
faces = fetch_olivetti_faces().images 

for i in range(5):
    for j in range(5):
        ax[i, j].xaxis.set_major_locator(plt.NullLocator())
        ax[i, j].yaxis.set_major_locator(plt.NullLocator())
        ax[i, j].imshow(faces[10 * i+j], cmap='binary_r')
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to /Users/manikamidha/scikit_learn_data

# %%
#  reduce or increase num of ticks
fig, ax = plt.subplots(4, 4, sharex=True, sharey=True)

# %%
for axi in ax.flat:
    # divide x and y axis in 3 parts 
    axi.xaxis.set_major_locator(plt.MaxNLocator(3))
    axi.yaxis.set_major_locator(plt.MaxNLocator(3))

fig

# %%
print(np.pi)
# Out:
# 3.141592653589793

# %%
print (r"$\pi$")
# Out:
# $\pi$

# %%
(2 * 4.71)/ 3.14
# Out:
# 3.0

# %%
4 % 2 #remainder
# Out:
# 0

# %%
(2 * 7.85)/ 3.14
# Out:
# 5.0

# %%
1.5 * 3.14
# Out:
# 4.71

# %%
4 // 2 # floor quotient
# Out:
# 2

# %%
6/4  # normal quotient
# Out:
# 1.5

# %%
6 // 4
# Out:
# 1

# %%
lst = [0, 1.57, 3.14, 4.71, 6.28, 7.85, 9.42]

def func(lst):
    for i in range(len(lst)):
        val = lst[i]
        print(f"val is {val}")
        N = int(np.round(2 * val/ np.pi))
        print(f"N is {N}")
        
func(lst)
# Out:
# val is 0
# N is 0
# val is 1.57
# N is 1
# val is 3.14
# N is 2
# val is 4.71
# N is 3
# val is 6.28
# N is 4
# val is 7.85
# N is 5
# val is 9.42
# N is 6

# %%
lst = [0, 1.57, 3.14, 4.71, 6.28, 7.85, 9.42]

def func(lst):
    for i in range(len(lst)):
        val = lst[i]
        
        N = int(np.round(2 * val/ np.pi))
        print(f"N is {N}")
        
        if N == 0:
            print(f"inside N == 0, val is {val}")
            print("0")
        elif N == 1:
            print(f"inside N == 1, val is {val}")
            print(r"$\pi/2$")
        elif N == 2:
            print(f"inside N == 2, val is {val}")
            print(r"$\pi$")
        elif N % 2 == 0:
            print(f"inside N % 2, val is {val}")
            print(rf"${N}\pi/2$")
        else:
            print(f"inside else, val is {val}")
            print(rf"${N // 2}\pi$")
            
        
func(lst)
# Out:
# N is 0
# inside N == 0, val is 0
# 0
# N is 1
# inside N == 1, val is 1.57
# $\pi/2$
# N is 2
# inside N == 2, val is 3.14
# $\pi$
# N is 3
# inside else, val is 4.71
# $1\pi$
# N is 4
# inside N % 2, val is 6.28
# $4\pi/2$
# N is 5
# inside else, val is 7.85
# $2\pi$
# N is 6
# inside N % 2, val is 9.42
# $6\pi/2$
