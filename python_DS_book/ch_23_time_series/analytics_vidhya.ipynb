# %%
# https://www.analyticsvidhya.com/blog/2021/12/stock-market-analysis-with-pandas-datareader-and-plotly-for-beginners/

# %%
import pandas as pd

# %%
from pandas_datareader import data as pdr
import yfinance as yf 
yf.pdr_override()

# %%
#Magnificient 7 stocks
tickers = ['AAPL', 'AMZN', 'GOOGL', 'META', 'MSFT', 'TSLA', 'NVDA']

# %%
df = pdr.DataReader(tickers, start='2020-01-01', end='2023-12-28', data_source='yahoo') #data_source='yahoo'
df.head()
# Out:
# [*********************100%***********************]  7 of 7 completed
#             Adj Close                                                \
#                  AAPL       AMZN      GOOGL        META        MSFT
# Date
# 2020-01-02  73.152649  94.900497  68.433998  209.779999  154.779495
# 2020-01-03  72.441452  93.748497  68.075996  208.669998  152.852234
# 2020-01-06  73.018692  95.143997  69.890503  212.600006  153.247330
# 2020-01-07  72.675270  95.343002  69.755501  213.059998  151.850037
# 2020-01-08  73.844368  94.598503  70.251999  215.220001  154.268768
#
#                                       Close                        ...  \
#                  NVDA       TSLA       AAPL       AMZN      GOOGL  ...
# Date                                                               ...
# 2020-01-02  59.744049  28.684000  75.087502  94.900497  68.433998  ...
# 2020-01-03  58.787785  29.534000  74.357498  93.748497  68.075996  ...
# ...

# %%
# multi_data = yf.download(tickers, start='2020-01-01', end='2023-12-28', data_source='yahoo')
# multi_data.head()

# %%
start_date = '2020-01-01'
end_date = '2023-12-28'
source = 'yahoo'

# %%
dfs = [] 
for sym in tickers:
    df = pdr.DataReader(sym, start=start_date, end=end_date, data_source='yahoo')
    dfs.append(df)
#     print(f"DF for {sym} is :")
#     print(df)
    
combined_df = pd.concat(dfs, axis=1)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2020-01-02  74.059998  75.150002  73.797501  75.087502  73.152657  135480400
# 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.441460  146322800
# 2020-01-06  73.447502  74.989998  73.187500  74.949997  73.018700  118387200
# 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.675293  108872000
# 2020-01-08  74.290001  76.110001  74.290001  75.797501  73.844345  132079200
#
# ...

# %%
print(combined_df.head(3))
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2020-01-02  74.059998  75.150002  73.797501  75.087502  73.152657  135480400
# 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.441460  146322800
# 2020-01-06  73.447502  74.989998  73.187500  74.949997  73.018700  118387200
#
#                  Open       High        Low      Close  ...        Low  \
# Date                                                    ...
# 2020-01-02  93.750000  94.900497  93.207497  94.900497  ...  28.114000
# 2020-01-03  93.224998  94.309998  93.224998  93.748497  ...  29.128000
# 2020-01-06  93.000000  95.184502  93.000000  95.143997  ...  29.333332
#
#                 Close  Adj Close     Volume       Open       High        Low  \
# Date
# 2020-01-02  28.684000  28.684000  142981500  59.687500  59.977501  59.180000
# 2020-01-03  29.534000  29.534000  266677500  58.775002  59.457500  58.525002
# ...

# %%
print(combined_df.shape)
# Out:
# (1004, 42)

# %%
print(combined_df.columns)
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Open', 'High',
#        'Low', 'Close', 'Adj Close', 'Volume', 'Open', 'High', 'Low', 'Close',
#        'Adj Close', 'Volume', 'Open', 'High', 'Low', 'Close', 'Adj Close',
#        'Volume', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Open',
#        'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Open', 'High', 'Low',
#        'Close', 'Adj Close', 'Volume'],
#       dtype='object')

# %%
#goog_df = pdr.DataReader(tickers, start=, end=, data_source='yahoo')

# %%
df_a = pdr.DataReader('AAPL', start='2020-01-01', end='2023-12-28', data_source='yahoo') #data_source='yahoo'
df_a.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  74.059998  75.150002  73.797501  75.087502  73.152657  135480400
# 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.441467  146322800
# 2020-01-06  73.447502  74.989998  73.187500  74.949997  73.018692  118387200
# 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.675270  108872000
# 2020-01-08  74.290001  76.110001  74.290001  75.797501  73.844345  132079200

# %%
df.columns.names = ['Stock Info']
print(df.head(3))
# Out:
# Stock Info       Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-01-02  59.687500  59.977501  59.180000  59.977501  59.744041  23753600
# 2020-01-03  58.775002  59.457500  58.525002  59.017502  58.787785  20538400
# 2020-01-06  58.080002  59.317501  57.817501  59.264999  59.034313  26263600
